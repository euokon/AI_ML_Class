# %% [markdown]
# #### Seaborn and Matplotlib (Visualization)

# %%
# pip install seaborn

# %%
# pip install matplotlib

# %% [markdown]
# 1. Distribution
# 2. Categorical
# 3. Regression: API | Tutorial
#
#
#
# References
#
# 1.[Statistical relationship](https://seaborn.pydata.org/tutorial/relational.html)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
## FAKE DATASET

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### STATISTICAL R/SHIP

# %%
sns.relplot(x="total_bill", y="tip", data=tips)

# %%
class Sns:
    def relpot(x, y, data):
        pass
    def categorical(x, y, data):
        pass
    def regression(x, y, data):
        pass

# %%
sns.relplot(x="total_bill", y="tip", hue="sex", data=tips)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)
# 1. What range do the observations cover?
# 2. What is their central tendency?
# 3. Are they heavily skewed in one direction? Is there evidence for bimodality?
# 4. Are there significant outliers?

# %%
sns.displot(tips, x="total_bill")

# %%
sns.displot(tips, x="total_bill", binwidth=3)

# %% [markdown]
# ### COUNT OF CATEGORICAL VARIABLES

# %%
sns.displot(tips, x="sex")

# %%
sns.displot(tips, x="time")

# %% [markdown]
# ### Conditioning on other variables

# %%
sns.displot(tips, x="total_bill", hue="sex", multiple="stack")

# %%
sns.displot(tips, x="total_bill", hue="sex", multiple="dodge")

# %%
sns.displot(tips, x="total_bill", col="sex")

# %%
sns.displot(tips, x="total_bill", col="time")

# %% [markdown]
# ### Plotting with categorical data
#
# Different types
# #### Categorical scatterplots:
#
# - stripplot() (with kind="strip"; the default)
#
# - swarmplot() (with kind="swarm")
#
# #### Categorical distribution plots:
#
# - boxplot() (with kind="box")
#
# - violinplot() (with kind="violin")
#
# - boxenplot() (with kind="boxen")
#
# ##### Categorical estimate plots:
#
# - pointplot() (with kind="point")
#
# - barplot() (with kind="bar")
#
# - countplot() (with kind="count")

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
cols = ['sex', 'smoker', 'day', 'time', 'size']
for col in cols:
    print(tips[col].unique())
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']
# [2 3 4 1 6 5]

# %%
sns.catplot(x="size", y="total_bill", data=tips)

# %%
sns.catplot(x="day", y="total_bill", data=tips)

# %%
sns.catplot(x="time", y="total_bill", kind="swarm", data=tips)

# %%
#hue ( seperator)
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips)

# %%
sns.catplot(x="total_bill", y="day", hue="time", kind="swarm", data=tips)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### BOXPLOT EXPLANATION
#
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary
# (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”)
# ![boxplot](boxplot.png)
#
# ## VIOLIN PLOT
# ![violin.png](attachment:violin.png)

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips)

# %%
#create new column
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  weekend
# 0         16.99  1.01  Female     No   Sun  Dinner     2     True
# 1         10.34  1.66    Male     No   Sun  Dinner     3     True
# 2         21.01  3.50    Male     No   Sun  Dinner     3     True
# 3         23.68  3.31    Male     No   Sun  Dinner     2     True
# 4         24.59  3.61  Female     No   Sun  Dinner     4     True
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     True
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     True
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     True
# 242       17.82  1.75    Male     No   Sat  Dinner     2     True
# 243       18.78  3.00  Female     No  Thur  Dinner     2    False
#
# [244 rows x 8 columns]

# %%
sns.catplot(x="day", y="total_bill", hue="weekend",
            kind="box", dodge=False, data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            kind="violin", data=tips)

# %%
# sns.catplot(x="total_bill", y="day", hue="sex",
#             kind="violin", data=tips)

# %% [markdown]
# ### ESTIMATE PLOT
#
# ### Bar plots
#  function to obtain the estimate (taking the mean by default)

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="total_bill", hue="smoker", kind="bar", data=tips)

# %%
sns.catplot(y="day", hue="sex", kind="count",
            palette="pastel", edgecolor=".6",
            data=tips)

# %%
sns.catplot(y="smoker", hue="sex", kind="count",
            palette="pastel", edgecolor=".6",
            data=tips)
