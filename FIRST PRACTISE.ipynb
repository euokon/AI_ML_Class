# %%
pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-0.24.2-cp39-cp39-macosx_10_13_x86_64.whl (7.3 MB)
# ...
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# ...
#   Using cached scipy-1.7.1-cp39-cp39-macosx_10_9_x86_64.whl (32.8 MB)
# ...
#   Using cached threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/apple/Desktop/emmanuel_ai_class/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# methods

def add_numbers (a, b):
    return a + b

# %%
x = add_numbers(1, 2)

# %%
x
# Out:
# 3

# %%
class Maths:
    def add(a,b):
        "add two numbers"
        return a + b
    
    def sub(a, b):
        "subtract a from b"
        return b - a

# %%
x = Maths.add(4,4)
x
# Out:
# 8

# %%
Maths.sub()

# %%
import pandas as pd
import numpy as np
pd.set_option("display.precision", 2)

# %%
data = pd.read_csv("data/creditcard.csv")

# %%
data.head(67)
# Out:
#     Time    V1    V2    V3    V4    V5    V6    V7    V8    V9  ...       V21  \
# 0    0.0 -1.36 -0.07  2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -1.83e-02
# 1    0.0  1.19  0.27  0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -2.26e-01
# 2    1.0 -1.36 -1.34  1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  2.48e-01
# 3    1.0 -0.97 -0.19  1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -1.08e-01
# 4    2.0 -1.16  0.88  1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -9.43e-03
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...       ...
# 62  41.0  1.15  0.58  0.19  2.60 -0.09 -1.04  0.53 -0.24 -0.90  ...  1.11e-02
# 63  42.0 -0.25  0.40  0.07 -1.06  2.41  3.74  0.32  0.67  0.02  ... -2.58e-01
# 64  42.0 -0.52  1.01  0.28  1.48 -0.71  0.36  1.56 -0.40 -0.48  ...  1.72e-01
# 65  44.0 -0.90  0.14  1.88 -0.21  1.05  1.91  0.24  0.65 -0.05  ... -8.15e-02
# 66  44.0 -0.71  0.51  1.82  0.62  0.85 -0.11  1.51 -0.80  0.24  ... -2.20e-01
#
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data["V1"] = data["V1"].astype("int64")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  int64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# showing statiscal distribution
# Out:
#             Time         V1        V2        V3        V4        V5        V6  \
# count  284807.00  284807.00  2.85e+05  2.85e+05  2.85e+05  2.85e+05  2.85e+05
# mean    94813.86       0.05  3.42e-16 -1.38e-15  2.07e-15  9.60e-16  1.49e-15
# std     47488.15       1.69  1.65e+00  1.52e+00  1.42e+00  1.38e+00  1.33e+00
# min         0.00     -56.00 -7.27e+01 -4.83e+01 -5.68e+00 -1.14e+02 -2.62e+01
# 25%     54201.50       0.00 -5.99e-01 -8.90e-01 -8.49e-01 -6.92e-01 -7.68e-01
# 50%     84692.00       0.00  6.55e-02  1.80e-01 -1.98e-02 -5.43e-02 -2.74e-01
# 75%    139320.50       1.00  8.04e-01  1.03e+00  7.43e-01  6.12e-01  3.99e-01
# max    172792.00       2.00  2.21e+01  9.38e+00  1.69e+01  3.48e+01  7.33e+01
#
#              V7        V8        V9  ...       V21       V22       V23  \
# count  2.85e+05  2.85e+05  2.85e+05  ...  2.85e+05  2.85e+05  2.85e+05
# mean  -5.56e-16  1.21e-16 -2.41e-15  ...  1.65e-16 -3.57e-16  2.58e-16
# ...

# %%
data['Class'].unique()
# Out:
# array([0, 1])

# %%
data['V7'].unique()
# Out:
# array([ 0.23959855, -0.07880298,  0.79146096, ..., -0.29682653,
#        -0.68617999,  1.57700625])

# %%
# data.describe(include=["object", "bool"])

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
data.sort_values(by="Amount", ascending=False).head(10)
# Out:
#             Time  V1     V2     V3     V4      V5     V6      V7     V8    V9  \
# 274771  166198.0 -35 -31.85 -48.33  15.30 -113.74  73.30  120.59 -27.35 -3.87
# 58465    48401.0 -36 -63.34 -20.65  16.72  -20.67   7.69   24.96  -4.73 -2.69
# 151296   95286.0 -34 -60.46 -21.34  16.88  -19.23   6.34   24.42  -4.96  0.19
# 46841    42951.0 -23 -42.17 -13.32   9.93  -13.95   5.56   15.71  -2.84 -1.58
# 54018    46253.0 -21 -38.31 -12.12   9.75  -12.88   4.26   14.79  -2.82 -0.67
# 169457  119713.0 -20 -37.94 -14.06  10.47  -10.87   6.26   14.96  -2.39 -0.60
# 284249  172273.0  -9 -11.11 -16.23   3.59  -40.43  23.92   44.05  -7.28 -4.21
# 227921  145283.0 -21 -34.70  -8.30  10.26    3.96  -3.23   -4.07  -4.08  0.55
# 74699    55709.0 -16 -16.42 -12.52   6.56  -27.75  18.07   28.50 -10.15  2.12
# 245474  152763.0 -14 -28.55 -12.71   5.88   -7.86   2.47   11.92  -2.65 -2.22
#
#         ...    V21    V22    V23   V24   V25   V26    V27    V28    Amount  \
# ...

# %%
data.sort_values(by=["Amount", "V27"], ascending=[False, False]).head(7)
# Out:
#             Time  V1     V2     V3     V4      V5     V6      V7     V8    V9  \
# 274771  166198.0 -35 -31.85 -48.33  15.30 -113.74  73.30  120.59 -27.35 -3.87
# 58465    48401.0 -36 -63.34 -20.65  16.72  -20.67   7.69   24.96  -4.73 -2.69
# 151296   95286.0 -34 -60.46 -21.34  16.88  -19.23   6.34   24.42  -4.96  0.19
# 46841    42951.0 -23 -42.17 -13.32   9.93  -13.95   5.56   15.71  -2.84 -1.58
# 54018    46253.0 -21 -38.31 -12.12   9.75  -12.88   4.26   14.79  -2.82 -0.67
# 169457  119713.0 -20 -37.94 -14.06  10.47  -10.87   6.26   14.96  -2.39 -0.60
# 284249  172273.0  -9 -11.11 -16.23   3.59  -40.43  23.92   44.05  -7.28 -4.21
#
#         ...    V21    V22    V23   V24   V25   V26    V27    V28    Amount  \
# 274771  ... -21.62   5.71  -1.58  4.58  4.55  3.42  31.61 -15.43  25691.16
# 58465   ...  11.46 -10.93 -17.17  1.18 -7.03 -2.53  -3.60   3.45  19656.53
# 151296  ...  11.50  -9.50 -16.51  0.74 -7.08 -2.60  -3.55   3.25  18910.00
# ...

# %%
data["Amount"].mean()
# Out:
# 88.34961925093133

# %%
data["Amount"].max()
# Out:
# 25691.16

# %%
data["Amount"].min()
# Out:
# 0.0

# %%
data["Amount"].std()
# Out:
# 250.1201092401885

# %%
data["Amount"].count()
# Out:
# 284807

# %%
#indexing

data[data["Class"] == 1].describe()
# Out:
#             Time      V1      V2      V3      V4      V5      V6      V7  \
# count     492.00  492.00  492.00  492.00  492.00  492.00  492.00  492.00
# mean    80746.81   -4.48    3.62   -7.03    4.54   -3.15   -1.40   -5.57
# std     47835.37    6.62    4.29    7.11    2.87    5.37    1.86    7.21
# min       406.00  -30.00   -8.40  -31.10   -1.31  -22.11   -6.41  -43.56
# 25%     41241.50   -6.00    1.19   -8.64    2.37   -4.79   -2.50   -7.97
# 50%     75568.50   -2.00    2.72   -5.08    4.18   -1.52   -1.42   -3.03
# 75%    128483.00    0.00    4.97   -2.28    6.35    0.21   -0.41   -0.95
# max    170348.00    2.00   22.06    2.25   12.11   11.10    6.47    5.80
#
#            V8      V9  ...     V21     V22     V23     V24     V25       V26  \
# count  492.00  492.00  ...  492.00  492.00  492.00  492.00  492.00  4.92e+02
# mean     0.57   -2.58  ...    0.71    0.01   -0.04   -0.11    0.04  5.16e-02
# std      6.80    2.50  ...    3.87    1.49    1.58    0.52    0.80  4.72e-01
# ...

# %%
data[data["Class"] == 0].describe()
# Out:
#             Time         V1        V2         V3        V4        V5  \
# count  284315.00  284315.00  2.84e+05  284315.00  2.84e+05  2.84e+05
# mean    94838.20       0.06 -6.27e-03       0.01 -7.86e-03  5.45e-03
# std     47484.02       1.65  1.64e+00       1.46  1.40e+00  1.36e+00
# min         0.00     -56.00 -7.27e+01     -48.33 -5.68e+00 -1.14e+02
# 25%     54230.00       0.00 -5.99e-01      -0.88 -8.50e-01 -6.89e-01
# 50%     84711.00       0.00  6.41e-02       0.18 -2.24e-02 -5.35e-02
# 75%    139333.00       1.00  8.00e-01       1.03  7.38e-01  6.12e-01
# max    172792.00       2.00  1.89e+01       9.38  1.69e+01  3.48e+01
#
#              V6        V7        V8        V9  ...       V21       V22  \
# count  2.84e+05  2.84e+05  2.84e+05  2.84e+05  ...  2.84e+05  2.84e+05
# mean   2.42e-03  9.64e-03 -9.87e-04  4.47e-03  ... -1.23e-03 -2.43e-05
# std    1.33e+00  1.18e+00  1.16e+00  1.09e+00  ...  7.17e-01  7.24e-01
# ...

# %%
data[data["Class"] == 1]['Amount'].mean()
# Out:
# 122.21132113821139

# %%
data[data["Class"] == 0]['Amount'].mean()
# Out:
# 88.29102242231328

# %%
s = "hellogglgllkglkbl"

# %%
s [:5]
# Out:
# 'hello'

# %%
s[5: 9]
# Out:
# ''

# %%
data.loc[0:5, "Class":"V27"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
data.apply(np.max)
# Out:
# Time      172792.00
# V1             2.00
# V2            22.06
# V3             9.38
# V4            16.88
# V5            34.80
# V6            73.30
# V7           120.59
# V8            20.01
# V9            15.59
# V10           23.75
# V11           12.02
# V12            7.85
# V13            7.13
# V14           10.53
# V15            8.88
# V16           17.32
# V17            9.25
# V18            5.04
# V19            5.59
# V20           39.42
# V21           27.20
# V22           10.50
# V23           22.53
# V24            4.58
# V25            7.52
# V26            3.52
# V27           31.61
# V28           33.85
# Amount     25691.16
# Class          1.00
# dtype: float64

# %%
columns_to_show = ["Amount", "V20"]

data.groupby(["Class"])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
#        Amount                              V20
#          mean     std amin      amax      mean   std   amin   amax
# Class
# 0       88.29  250.11  0.0  25691.16 -6.44e-04  0.77 -54.50  39.42
# 1      122.21  256.68  0.0   2125.87  3.72e-01  1.35  -4.13  11.06

# %%
data.pivot_table(
    ["Amount", "V20", "V17"],
    ["Class"],
    aggfunc="mean",
)
# Out:
#        Amount   V17       V20
# Class
# 0       88.29  0.01 -6.44e-04
# 1      122.21 -6.67  3.72e-01

# %%
data.head()
# Out:
#    Time  V1    V2    V3    V4    V5    V6    V7    V8    V9  ...       V21  \
# 0   0.0  -1 -0.07  2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -1.83e-02
# 1   0.0   1  0.27  0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -2.26e-01
# 2   1.0  -1 -1.34  1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  2.48e-01
# 3   1.0   0 -0.19  1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -1.08e-01
# 4   2.0  -1  0.88  1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -9.43e-03
#
#         V22   V23   V24   V25   V26       V27   V28  Amount  Class
# 0  2.78e-01 -0.11  0.07  0.13 -0.19  1.34e-01 -0.02  149.62      0
# 1 -6.39e-01  0.10 -0.34  0.17  0.13 -8.98e-03  0.01    2.69      0
# 2  7.72e-01  0.91 -0.69 -0.33 -0.14 -5.54e-02 -0.06  378.66      0
# 3  5.27e-03 -0.19 -1.18  0.65 -0.22  6.27e-02  0.06  123.50      0
# 4  7.98e-01 -0.14  0.14 -0.21  0.50  2.19e-01  0.22   69.99      0
#
# [5 rows x 31 columns]

# %%
data["percent_amount"] = data["Amount"]/100

# %%
data.head()
# Out:
#    Time  V1    V2    V3    V4    V5    V6    V7    V8    V9  ...       V22  \
# 0   0.0  -1 -0.07  2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ...  2.78e-01
# 1   0.0   1  0.27  0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -6.39e-01
# 2   1.0  -1 -1.34  1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  7.72e-01
# 3   1.0   0 -0.19  1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ...  5.27e-03
# 4   2.0  -1  0.88  1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ...  7.98e-01
#
#     V23   V24   V25   V26       V27   V28  Amount  Class  percent_amount
# 0 -0.11  0.07  0.13 -0.19  1.34e-01 -0.02  149.62      0            1.50
# 1  0.10 -0.34  0.17  0.13 -8.98e-03  0.01    2.69      0            0.03
# 2  0.91 -0.69 -0.33 -0.14 -5.54e-02 -0.06  378.66      0            3.79
# 3 -0.19 -1.18  0.65 -0.22  6.27e-02  0.06  123.50      0            1.24
# 4 -0.14  0.14 -0.21  0.50  2.19e-01  0.22   69.99      0            0.70
#
# [5 rows x 32 columns]

# %%
data["sum of v tables "] = data['V20'] + data['V17'] + data['V8']

# %%
data.head()
# Out:
#    Time  V1    V2    V3    V4    V5    V6    V7    V8    V9  ...   V23   V24  \
# 0   0.0  -1 -0.07  2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -0.11  0.07
# 1   0.0   1  0.27  0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ...  0.10 -0.34
# 2   1.0  -1 -1.34  1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  0.91 -0.69
# 3   1.0   0 -0.19  1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -0.19 -1.18
# 4   2.0  -1  0.88  1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -0.14  0.14
#
#     V25   V26       V27   V28  Amount  Class  percent_amount  sum of v tables
# 0  0.13 -0.19  1.34e-01 -0.02  149.62      0            1.50              0.56
# 1  0.17  0.13 -8.98e-03  0.01    2.69      0            0.03             -0.10
# 2 -0.33 -0.14 -5.54e-02 -0.06  378.66      0            3.79              1.88
# 3  0.65 -0.22  6.27e-02  0.06  123.50      0            1.24             -0.51
# 4 -0.21  0.50  2.19e-01  0.22   69.99      0            0.70             -0.10
#
# [5 rows x 33 columns]

# %%
data['accounting'] = data['V2'] + 0.15 - 1/3 *  data['Amount'] * 0.003

# %%
data.head()
# Out:
#    Time  V1    V2    V3    V4    V5    V6    V7    V8    V9  ...   V24   V25  \
# 0   0.0  -1 -0.07  2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ...  0.07  0.13
# 1   0.0   1  0.27  0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -0.34  0.17
# 2   1.0  -1 -1.34  1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ... -0.69 -0.33
# 3   1.0   0 -0.19  1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -1.18  0.65
# 4   2.0  -1  0.88  1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ...  0.14 -0.21
#
#     V26       V27   V28  Amount  Class  percent_amount  sum of v tables   \
# 0 -0.19  1.34e-01 -0.02  149.62      0            1.50              0.56
# 1  0.13 -8.98e-03  0.01    2.69      0            0.03             -0.10
# 2 -0.14 -5.54e-02 -0.06  378.66      0            3.79              1.88
# 3 -0.22  6.27e-02  0.06  123.50      0            1.24             -0.51
# 4  0.50  2.19e-01  0.22   69.99      0            0.70             -0.10
#
#    accounting
# 0       -0.07
# 1        0.41
# 2       -1.57
# ...

# %%
data[['accounting','V2','Amount']]
# Out:
#         accounting     V2  Amount
# 0            -0.07  -0.07  149.62
# 1             0.41   0.27    2.69
# 2            -1.57  -1.34  378.66
# 3            -0.16  -0.19  123.50
# 4             0.96   0.88   69.99
# ...            ...    ...     ...
# 284802       10.22  10.07    0.77
# 284803        0.07  -0.06   24.79
# 284804       -0.22  -0.30   67.88
# 284805        0.67   0.53   10.00
# 284806       -0.26  -0.19  217.00
#
# [284807 rows x 3 columns]

# %% [markdown]
# # Visualization

# %%
pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 292 kB 441 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.2 MB 131 kB/s eta 0:00:01     |███████████████████████████     | 6.1 MB 973 kB/s eta 0:00:02     |███████████████████████████▎    | 6.1 MB 973 kB/s eta 0:00:02
# ...
#      |████████████████████████████████| 3.0 MB 283 kB/s eta 0:00:01
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#      |████████████████████████████████| 61 kB 431 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/apple/Desktop/emmanuel_ai_class/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# some imports to set up plotting
import matplotlib.pyplot as plt
# pip install seaborn
import seaborn as sns

# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
sns.countplot(x="Class", data=data);

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64
